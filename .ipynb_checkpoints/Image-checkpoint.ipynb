# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
Im=Image.open("Tirth.jpg")

# %%
Im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x1267 at 0x21564C60DC8>

# %%
arr = np.array(Im)

# %%
arr.shape
# Out:
# (1267, 640, 3)

# %%
copy = arr.copy()
copy[:,:,[1,2]] = 255

# %%
plt.imshow(copy)

# %%
gray=arr.mean(axis=2)

# %%
plt.imshow(gray,cmap='gray')
